# %% [markdown]
# # Importing Libraries

# %%
# importing libraries
import pandas as pd
import numpy as np
import os

# %% [markdown]
# # Importing Data

# %%
# setting a path
path = '/Users/tannu/Desktop/Data Analytics/Instacart Basket Analysis Dec-2025 '

# %%
# importing data
df_ords_prods_merge = pd.read_pickle(os.path.join(path, '2 Data', 'Prepared Data', 'ords_prods_merge_new.pkl'))

# %%
# creating a subset of the first million rows
df = df_ords_prods_merge[:1000000]

# %%
df.shape
# Out:
# (1000000, 17)

# %%
df.head(2)
# Out:
#    product_id                product_name  aisle_id  department_id  prices  \
# 0           1  Chocolate Sandwich Cookies        61             19     5.8
# 1           1  Chocolate Sandwich Cookies        61             19     5.8
#
#    order_id  user_id  order_number  orders_day_of_the_week  order_hour_of_day  \
# 0   3139998      138            28                       6                 11
# 1   1977647      138            30                       6                 17
#
#    days_since_prior_order  add_to_cart_order  reordered _merge  \
# 0                     3.0                  5          0   both
# 1                    20.0                  1          1   both
#
#          price_range     busiest_day   busiest_hours
# 0  Mid-range product  Regularly Busy     Most Orders
# 1  Mid-range product  Regularly Busy  Average Orders

# %% [markdown]
# # Grouping Data

# %%
# grouping data
df.groupby('product_name')

# %% [markdown]
# # Aggregating Data

# %%
# grouping bu 'department_id' and aggregating mean of 'order_number'
df.groupby('department_id').agg({'order_number': ['mean']})
# Out:
#               order_number
#                       mean
# department_id
# 1                15.577493
# 2                17.320781
# 3                16.084944
# 4                17.530458
# 5                14.763075
# 6                16.658449
# 7                17.031590
# 8                15.076662
# 9                15.447580
# 10               18.681852
# 11               15.447411
# 12               14.327957
# 13               16.548642
# 14               16.960241
# 15               16.121948
# 16               17.803851
# 17               15.593633
# 18               19.674252
# 19               16.899756
# 20               16.255442
# 21               25.535479

# %%
# performing multiple aggregation
df.groupby('department_id').agg({'order_number': ['mean', 'min', 'max']})
# Out:
#               order_number
#                       mean min max
# department_id
# 1                15.577493   1  99
# 2                17.320781   1  96
# 3                16.084944   1  99
# 4                17.530458   1  99
# 5                14.763075   1  99
# 6                16.658449   1  99
# 7                17.031590   1  99
# 8                15.076662   1  98
# 9                15.447580   1  99
# 10               18.681852   1  99
# 11               15.447411   1  99
# 12               14.327957   1  99
# 13               16.548642   1  99
# 14               16.960241   1  99
# 15               16.121948   1  99
# 16               17.803851   1  99
# 17               15.593633   1  99
# 18               19.674252   1  99
# 19               16.899756   1  99
# 20               16.255442   1  99
# 21               25.535479   1  98

# %%
# aggregating data with transform()
df_ords_prods_merge['max_order'] = df_ords_prods_merge.groupby(['user_id'])['order_number'].transform(np.max)
# Out:
# /var/folders/z8/12vdbzn57fx_ky9_g3vm3lv80000gn/T/ipykernel_23030/3596540814.py:2: FutureWarning: The provided callable <function max at 0x11b441620> is currently using SeriesGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   df_ords_prods_merge['max_order'] = df_ords_prods_merge.groupby(['user_id'])['order_number'].transform(np.max)

# %%
df_ords_prods_merge.head()
# Out:
#    product_id                product_name  aisle_id  department_id  prices  \
# 0           1  Chocolate Sandwich Cookies        61             19     5.8
# 1           1  Chocolate Sandwich Cookies        61             19     5.8
# 2           1  Chocolate Sandwich Cookies        61             19     5.8
# 3           1  Chocolate Sandwich Cookies        61             19     5.8
# 4           1  Chocolate Sandwich Cookies        61             19     5.8
#
#    order_id  user_id  order_number  orders_day_of_the_week  order_hour_of_day  \
# 0   3139998      138            28                       6                 11
# 1   1977647      138            30                       6                 17
# 2    389851      709             2                       0                 21
# 3    652770      764             1                       3                 13
# 4   1813452      764             3                       4                 17
#
# ...

# %%
df_ords_prods_merge['max_order'].value_counts(dropna = False)
# Out:
# max_order
# 99    1171333
# 8      811843
# 6      811396
# 9      810213
# 7      803979
#        ...
# 97      44949
# 98      44587
# 96      40453
# 2           6
# 1           5
# Name: count, Length: 99, dtype: int64

# %%
df_ords_prods_merge.head(100)

# %% [markdown]
# # Deriving a New Column

# %%
# creating a new column using the loc() function
df_ords_prods_merge.loc[df_ords_prods_merge['max_order']>40, 'loyalty_flag'] = 'Loyal Customer'

# %%
df_ords_prods_merge.loc[(df_ords_prods_merge['max_order']<=40) & (df_ords_prods_merge['max_order']>10), 'loyalty_flag'] = 'Regular Customer'

# %%
df_ords_prods_merge.loc[df_ords_prods_merge['max_order']<=10, 'loyalty_flag'] = 'New Customer'

# %%
df_ords_prods_merge.columns
# Out:
# Index(['product_id', 'product_name', 'aisle_id', 'department_id', 'prices',
#        'order_id', 'user_id', 'order_number', 'orders_day_of_the_week',
#        'order_hour_of_day', 'days_since_prior_order', 'add_to_cart_order',
#        'reordered', '_merge', 'price_range', 'busiest_day', 'busiest_hours',
#        'max_order', 'loyalty_flag'],
#       dtype='object')

# %%
df_ords_prods_merge['loyalty_flag'].value_counts(dropna = False)
# Out:
# loyalty_flag
# Regular Customer    15876776
# Loyal Customer      10284093
# New Customer         6243990
# Name: count, dtype: int64

# %%
# Displaying the top 60 rows of only the columns specified
df_ords_prods_merge[['user_id', 'loyalty_flag', 'order_number']].head(60)
# Out:
#     user_id      loyalty_flag  order_number
# 0       138  Regular Customer            28
# 1       138  Regular Customer            30
# 2       709      New Customer             2
# 3       764      New Customer             1
# 4       764      New Customer             3
# 5       777  Regular Customer            16
# 6       825      New Customer             3
# 7       910  Regular Customer            12
# 8      1052  Regular Customer            10
# 9      1052  Regular Customer            15
# 10     1379      New Customer             1
# 11     1480    Loyal Customer            36
# 12     1480    Loyal Customer            38
# 13     1480    Loyal Customer            39
# 14     1494  Regular Customer             6
# 15     1494  Regular Customer             7
# 16     1494  Regular Customer             9
# 17     1540  Regular Customer             4
# 18     1540  Regular Customer             5
# 19     1540  Regular Customer             6
# ...

# %%
df_ords_prods_merge.head(2)
# Out:
#    product_id                product_name  aisle_id  department_id  prices  \
# 0           1  Chocolate Sandwich Cookies        61             19     5.8
# 1           1  Chocolate Sandwich Cookies        61             19     5.8
#
#    order_id  user_id  order_number  orders_day_of_the_week  order_hour_of_day  \
# 0   3139998      138            28                       6                 11
# 1   1977647      138            30                       6                 17
#
#    days_since_prior_order  add_to_cart_order  reordered _merge  \
# 0                     3.0                  5          0   both
# 1                    20.0                  1          1   both
#
#          price_range     busiest_day   busiest_hours  max_order  \
# 0  Mid-range product  Regularly Busy     Most Orders         32
# 1  Mid-range product  Regularly Busy  Average Orders         32
#
#        loyalty_flag
# 0  Regular Customer
# 1  Regular Customer
